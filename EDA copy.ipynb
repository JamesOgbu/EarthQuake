# %% [markdown]
# # Import required libraries

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.geocoders import Nominatim
import pycountry_convert as pc

# %%
df = pd.read_csv("earthquake_data.csv")

df.head(5)
# Out:
#                                           title  magnitude         date_time  \
# 0  M 7.0 - 18 km SW of Malango, Solomon Islands        7.0  22-11-2022 02:03
# 1      M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9  18-11-2022 13:37
# 2                                      M 7.0 -         7.0  12-11-2022 07:09
# 3           M 7.3 - 205 km ESE of Neiafu, Tonga        7.3  11-11-2022 10:48
# 4                                      M 6.6 -         6.6  09-11-2022 10:14
#
#    cdi  mmi  alert  tsunami  sig net  nst   dmin   gap magType    depth  \
# 0    8    7  green        1  768  us  117  0.509  17.0     mww   14.000
# 1    4    4  green        0  735  us   99  2.229  34.0     mww   25.000
# 2    3    3  green        1  755  us  147  3.125  18.0     mww  579.000
# 3    5    5  green        1  833  us  149  1.865  21.0     mww   37.000
# 4    0    2  green        1  670  us  131  4.998  27.0     mww  624.464
#
#    latitude  longitude                  location continent          country
# 0   -9.7963    159.596  Malango, Solomon Islands   Oceania  Solomon Islands
# 1   -4.9559    100.738       Bengkulu, Indonesia       NaN              NaN
# 2  -20.0508   -178.346                       NaN   Oceania             Fiji
# 3  -19.2918   -172.129             Neiafu, Tonga       NaN              NaN
# 4  -25.5948    178.278                       NaN       NaN              NaN

# %% [markdown]
# missing data heatmap

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df.isna(), cmap='Greys', yticklabels=False)
plt.title('Missing Data Heatmap')
plt.show()

# %% [markdown]
# Try finding the country and continent based on the location with geopy library

# %% [markdown]
# making use of the already aquired countries to fill in the continent column

# %% [markdown]
# Heatmap showing missing data after adding countries and continent

# %%
df.to_csv('earthquake1.csv', index= False)

# %%
df=pd.read_csv("earthquake5.csv")
plt.figure(figsize=(10,5))
sns.heatmap(df.isna(), cmap='Greys', yticklabels=False)
plt.title('Missing Data Heatmap')
plt.show()

# %%
#use the updated country to get the continents

def update_continents(df2):
    for index, row in df.iterrows():
        country = row['country']
        if not pd.isnull(country):
            try:
                # Convert country to continent
                country_alpha2 = pc.country_name_to_country_alpha2(country)
                continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
                continent = pc.convert_continent_code_to_continent_name(continent_code)

                # Update the DataFrame
                df.at[index, 'continent'] = continent

                print(f"Updated continent for country '{country}'")

            except Exception as e:
                print(f"Error updating continent for country '{country}': {str(e)}")

    return df

# Example usage
input_file = 'earthquake1.csv'
output_file = 'earthquake5.csv'

df2 = pd.read_csv(input_file)
df_updated = update_continents(df2)
df_updated.to_csv(output_file, index=False)
print(f"Saved updated DataFrame to '{output_file}'")
# Out:
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Tonga'
# Error updating continent for country 'the Fiji Islands': "Invalid Country Name: 'the Fiji Islands'"
# Error updating continent for country 'the Fiji Islands': "Invalid Country Name: 'the Fiji Islands'"
# Updated continent for country 'Panama'
# Updated continent for country 'Mexico'
# Updated continent for country 'Mexico'
# Updated continent for country 'Taiwan'
# Updated continent for country 'Taiwan'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'China'
# Error updating continent for country 'the Kermadec Islands': "Invalid Country Name: 'the Kermadec Islands'"
# Updated continent for country 'Philippines'
# Updated continent for country 'Brazil'
# Updated continent for country 'Peru'
# Updated continent for country 'Argentina'
# Updated continent for country 'Nicaragua'
# Error updating continent for country 'the Loyalty Islands': "Invalid Country Name: 'the Loyalty Islands'"
# Updated continent for country 'New Caledonia'
# Updated continent for country 'Taiwan'
# Updated continent for country 'Japan'
# Updated continent for country 'Indonesia'
# Updated continent for country 'New Zealand'
# Error updating continent for country 'the Fiji Islands': "Invalid Country Name: 'the Fiji Islands'"
# Updated continent for country 'Peru'
# Error updating continent for country 'Kermadec Islands region': "Invalid Country Name: 'Kermadec Islands region'"
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Cyprus'
# Updated continent for country 'China'
# Error updating continent for country 'Timor Leste': "Invalid Country Name: 'Timor Leste'"
# Error updating continent for country 'Flores Sea': "Invalid Country Name: 'Flores Sea'"
# Updated continent for country 'Peru'
# Updated continent for country 'Japan'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Vanuatu region': "Invalid Country Name: 'Vanuatu region'"
# Error updating continent for country 'Vanuatu region': "Invalid Country Name: 'Vanuatu region'"
# Updated continent for country 'Nicaragua'
# Updated continent for country 'Mexico'
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Updated continent for country 'Vanuatu'
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Updated continent for country 'Haiti'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Updated continent for country 'Philippines'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Philippines'
# Updated continent for country 'Panama'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Wallis and Futuna'
# Updated continent for country 'China'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Mauritius - Reunion region': "Invalid Country Name: 'Mauritius - Reunion region'"
# Updated continent for country 'Tonga'
# Updated continent for country 'Tonga'
# Updated continent for country 'Japan'
# Updated continent for country 'Russia'
# Error updating continent for country 'Kermadec Islands region': "Invalid Country Name: 'Kermadec Islands region'"
# Updated continent for country 'New Zealand'
# Updated continent for country 'New Zealand'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Japan'
# Error updating continent for country 'the Loyalty Islands': "Invalid Country Name: 'the Loyalty Islands'"
# Error updating continent for country 'South Shetland Islands': "Invalid Country Name: 'South Shetland Islands'"
# Updated continent for country 'Philippines'
# Updated continent for country 'Mongolia'
# Updated continent for country 'Chile'
# Updated continent for country 'Greece'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'central Mid-Atlantic Ridge': "Invalid Country Name: 'central Mid-Atlantic Ridge'"
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Error updating continent for country 'central Mid-Atlantic Ridge': "Invalid Country Name: 'central Mid-Atlantic Ridge'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Philippines'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Mexico'
# Error updating continent for country 'the Kermadec Islands': "Invalid Country Name: 'the Kermadec Islands'"
# Updated continent for country 'Japan'
# Updated continent for country 'Chile'
# Error updating continent for country 'NV Earthquake': "Invalid Country Name: 'NV Earthquake'"
# Updated continent for country 'Solomon Islands'
# Error updating continent for country 'Banda Sea': "Invalid Country Name: 'Banda Sea'"
# Updated continent for country 'Greece'
# Error updating continent for country 'Idaho': "Invalid Country Name: 'Idaho'"
# Updated continent for country 'Russia'
# Updated continent for country 'Russia'
# Updated continent for country 'Jamaica'
# Updated continent for country 'Turkey'
# Updated continent for country 'Philippines'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Fiji'
# Updated continent for country 'Tonga'
# Updated continent for country 'Philippines'
# Updated continent for country 'Philippines'
# Updated continent for country 'Chile'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Fiji'
# Error updating continent for country 'South Sandwich Islands': "Invalid Country Name: 'South Sandwich Islands'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Chile'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Australia'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'CA': argument of type 'functools._lru_cache_wrapper' is not iterable
# Updated continent for country 'Indonesia'
# Updated continent for country 'New Zealand'
# Updated continent for country 'El Salvador'
# Updated continent for country 'Peru'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'South Sandwich Islands': "Invalid Country Name: 'South Sandwich Islands'"
# Updated continent for country 'Peru'
# Updated continent for country 'Ecuador'
# Updated continent for country 'Mexico'
# Error updating continent for country 'Prince Edward Islands region': "Invalid Country Name: 'Prince Edward Islands region'"
# Updated continent for country 'Chile'
# Updated continent for country 'Vanuatu'
# Error updating continent for country 'Molucca Sea': "Invalid Country Name: 'Molucca Sea'"
# Updated continent for country 'Brazil'
# Updated continent for country 'Philippines'
# Updated continent for country 'Russia'
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Updated continent for country 'New Caledonia'
# Updated continent for country 'New Caledonia'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Fiji'
# Updated continent for country 'Svalbard and Jan Mayen'
# Updated continent for country 'Greece'
# Updated continent for country 'Canada'
# Updated continent for country 'Canada'
# Updated continent for country 'Canada'
# Updated continent for country 'New Caledonia'
# Updated continent for country 'Russia'
# Updated continent for country 'Russia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Fiji'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'the Fiji Islands': "Invalid Country Name: 'the Fiji Islands'"
# Error updating continent for country 'Kermadec Islands region': "Invalid Country Name: 'Kermadec Islands region'"
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Fiji'
# Updated continent for country 'Japan'
# Updated continent for country 'New Caledonia'
# Updated continent for country 'Peru'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Venezuela'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Fiji'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Hawaii': "Invalid Country Name: 'Hawaii'"
# Updated continent for country 'Bolivia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Mexico'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Peru'
# Updated continent for country 'Honduras'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Bouvet Island region': "Invalid Country Name: 'Bouvet Island region'"
# Updated continent for country 'New Caledonia'
# Updated continent for country 'New Caledonia'
# Updated continent for country 'Costa Rica'
# Updated continent for country 'Iraq'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Tonga'
# Updated continent for country 'New Caledonia'
# Updated continent for country 'New Caledonia'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Mexico'
# Updated continent for country 'Mexico'
# Updated continent for country 'China'
# Updated continent for country 'Greece'
# Error updating continent for country 'Russia region': "Invalid Country Name: 'Russia region'"
# Error updating continent for country 'New Zealand region': "Invalid Country Name: 'New Zealand region'"
# Updated continent for country 'Philippines'
# Updated continent for country 'Guatemala'
# Updated continent for country 'Guatemala'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Indonesia'
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Philippines'
# Updated continent for country 'Chile'
# Updated continent for country 'Botswana'
# Updated continent for country 'Russia'
# Error updating continent for country 'the Fiji Islands': "Invalid Country Name: 'the Fiji Islands'"
# Updated continent for country 'Bolivia'
# Updated continent for country 'Philippines'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Philippines'
# Updated continent for country 'Fiji'
# Updated continent for country 'Chile'
# Error updating continent for country 'Timor Leste': "Invalid Country Name: 'Timor Leste'"
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Error updating continent for country 'California': "Invalid Country Name: 'California'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Tajikistan'
# Updated continent for country 'El Salvador'
# Updated continent for country 'Japan'
# Updated continent for country 'New Zealand'
# Updated continent for country 'New Zealand'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Italy'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Papua New Guinea'
# Error updating continent for country 'Fiji region': "Invalid Country Name: 'Fiji region'"
# Updated continent for country 'New Zealand'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Myanmar'
# Error updating continent for country 'the Loyalty Islands': "Invalid Country Name: 'the Loyalty Islands'"
# Updated continent for country 'Northern Mariana Islands'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Updated continent for country 'Ecuador'
# Updated continent for country 'Ecuador'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Ecuador'
# Updated continent for country 'Japan'
# Updated continent for country 'Myanmar'
# Updated continent for country 'Afghanistan'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Russia'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Mexico'
# Updated continent for country 'Japan'
# Updated continent for country 'Philippines'
# Updated continent for country 'India'
# Updated continent for country 'Mexico'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Tajikistan'
# Updated continent for country 'Brazil'
# Updated continent for country 'Peru'
# Updated continent for country 'Peru'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Greece'
# Updated continent for country 'Japan'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Error updating continent for country 'India region': "Invalid Country Name: 'India region'"
# Updated continent for country 'Chile'
# Error updating continent for country 'Timor Leste': "Invalid Country Name: 'Timor Leste'"
# Updated continent for country 'Afghanistan'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Mexico'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Barbados'
# Updated continent for country 'Solomon Islands'
# Error updating continent for country 'Japan region': "Invalid Country Name: 'Japan region'"
# Error updating continent for country 'Japan region': "Invalid Country Name: 'Japan region'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Japan'
# Updated continent for country 'Nepal'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Nepal'
# Updated continent for country 'Nepal'
# Updated continent for country 'Nepal'
# Updated continent for country 'Wallis and Futuna'
# Updated continent for country 'Tonga'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Japan'
# Updated continent for country 'Argentina'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Panama'
# Updated continent for country 'Panama'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Philippines'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Papua New Guinea'
# Error updating continent for country 'Fiji region': "Invalid Country Name: 'Fiji region'"
# Updated continent for country 'El Salvador'
# Updated continent for country 'Guam'
# Updated continent for country 'Peru'
# Error updating continent for country 'Micronesia region': "Invalid Country Name: 'Micronesia region'"
# Error updating continent for country 'Fiji region': "Invalid Country Name: 'Fiji region'"
# Updated continent for country 'Japan'
# Updated continent for country 'Mexico'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Wallis and Futuna'
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'New Zealand'
# Updated continent for country 'New Zealand'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Greece'
# Updated continent for country 'Panama'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Canada'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Mexico'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Nicaragua'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Error updating continent for country 'California': "Invalid Country Name: 'California'"
# Updated continent for country 'Japan'
# Updated continent for country 'Barbados'
# Updated continent for country 'China'
# Updated continent for country 'Vanuatu'
# Error updating continent for country 'the Kermadec Islands': "Invalid Country Name: 'the Kermadec Islands'"
# Updated continent for country 'Vanuatu'
# Error updating continent for country 'Fiji region': "Invalid Country Name: 'Fiji region'"
# Error updating continent for country 'Scotia Sea': "Invalid Country Name: 'Scotia Sea'"
# Error updating continent for country 'Scotia Sea': "Invalid Country Name: 'Scotia Sea'"
# Updated continent for country 'Chile'
# Updated continent for country 'Japan'
# Updated continent for country 'Mexico'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Philippines'
# Updated continent for country 'Greece'
# Error updating continent for country 'Okhotsk': "Invalid Country Name: 'Okhotsk'"
# Updated continent for country 'New Zealand'
# Updated continent for country 'Pakistan'
# Updated continent for country 'Peru'
# Updated continent for country 'Pakistan'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Error updating continent for country 'Japan region': "Invalid Country Name: 'Japan region'"
# Error updating continent for country 'Timor Leste': "Invalid Country Name: 'Timor Leste'"
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'New Zealand'
# Updated continent for country 'Colombia'
# Updated continent for country 'New Zealand'
# Error updating continent for country 'South Sandwich Islands region': "Invalid Country Name: 'South Sandwich Islands region'"
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Error updating continent for country 'northern Mid-Atlantic Ridge': "Invalid Country Name: 'northern Mid-Atlantic Ridge'"
# Updated continent for country 'Nicaragua'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Okhotsk': "Invalid Country Name: 'Okhotsk'"
# Error updating continent for country 'Okhotsk': "Invalid Country Name: 'Okhotsk'"
# Updated continent for country 'Tonga'
# Updated continent for country 'Northern Mariana Islands'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'China'
# Updated continent for country 'Russia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Iran'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Russia'
# Updated continent for country 'Russia'
# Updated continent for country 'Russia'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Colombia'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Japan'
# Updated continent for country 'Chile'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Vanuatu'
# Error updating continent for country 'Banda Sea': "Invalid Country Name: 'Banda Sea'"
# Updated continent for country 'Japan'
# Updated continent for country 'Guatemala'
# Updated continent for country 'Myanmar'
# Updated continent for country 'Guatemala'
# Updated continent for country 'Canada'
# Updated continent for country 'Costa Rica'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Colombia'
# Updated continent for country 'Costa Rica'
# Updated continent for country 'Philippines'
# Updated continent for country 'El Salvador'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Russia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Tonga'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Chile'
# Updated continent for country 'Mexico'
# Updated continent for country 'Mexico'
# Error updating continent for country 'off the west coast of northern Sumatra': "Invalid Country Name: 'off the west coast of northern Sumatra'"
# Error updating continent for country 'off the west coast of northern Sumatra': "Invalid Country Name: 'off the west coast of northern Sumatra'"
# Updated continent for country 'Chile'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Mexico'
# Updated continent for country 'Russia'
# Updated continent for country 'Philippines'
# Updated continent for country 'Vanuatu'
# Error updating continent for country 'off the west coast of northern Sumatra': "Invalid Country Name: 'off the west coast of northern Sumatra'"
# Updated continent for country 'Russia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Mexico'
# Updated continent for country 'Peru'
# Updated continent for country 'Turkey'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'India'
# Updated continent for country 'Japan'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Peru'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Papua New Guinea'
# Error updating continent for country 'Kermadec Islands region': "Invalid Country Name: 'Kermadec Islands region'"
# Updated continent for country 'Japan'
# Updated continent for country 'New Caledonia'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Mexico'
# Updated continent for country 'Myanmar'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Pakistan'
# Updated continent for country 'New Caledonia'
# Updated continent for country 'Chile'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Iran'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Mexico'
# Updated continent for country 'Indonesia'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Ecuador'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Philippines'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Chile'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'India region': "Invalid Country Name: 'India region'"
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Indonesia'
# Updated continent for country 'China'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'MX': argument of type 'functools._lru_cache_wrapper' is not iterable
# Updated continent for country 'India'
# Updated continent for country 'Chile'
# Updated continent for country 'Japan'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Chile'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Japan'
# Updated continent for country 'Haiti'
# Error updating continent for country 'California': "Invalid Country Name: 'California'"
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Chile'
# Updated continent for country 'Fiji'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Japan'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Samoa'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Japan'
# Updated continent for country 'India'
# Updated continent for country 'Japan'
# Updated continent for country 'Mexico'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Honduras'
# Updated continent for country 'Tonga'
# Updated continent for country 'Philippines'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Afghanistan'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Mexico'
# Updated continent for country 'Kyrgyzstan'
# Updated continent for country 'Japan'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Nepal'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'India'
# Updated continent for country 'Japan'
# Updated continent for country 'China'
# Updated continent for country 'Japan'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'China'
# Error updating continent for country 'Philippine Islands region': "Invalid Country Name: 'Philippine Islands region'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Greece'
# Updated continent for country 'Greece'
# Updated continent for country 'Mexico'
# Updated continent for country 'New Zealand'
# Error updating continent for country 'Ant': "Invalid Country Alpha-3 code: 'Ant'"
# Updated continent for country 'Martinique'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Ecuador'
# Error updating continent for country 'Ant': "Invalid Country Alpha-3 code: 'Ant'"
# Updated continent for country 'Chile'
# Updated continent for country 'Indonesia'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Colombia'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Peru'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Guatemala'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Japan'
# Updated continent for country 'Vanuatu'
# Error updating continent for country 'S': "Invalid Country Name: 'S'"
# Updated continent for country 'Indonesia'
# Error updating continent for country 'the Kuril Islands': "Invalid Country Name: 'the Kuril Islands'"
# Updated continent for country 'Taiwan'
# Updated continent for country 'Taiwan'
# Error updating continent for country 'Kuril Islands': "Invalid Country Name: 'Kuril Islands'"
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Peru'
# Updated continent for country 'Papua New Guinea'
# Error updating continent for country 'Hawaii': "Invalid Country Name: 'Hawaii'"
# Updated continent for country 'Tonga'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Russia'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Russia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Tonga'
# Updated continent for country 'Tonga'
# Updated continent for country 'Chile'
# Updated continent for country 'Chile'
# Updated continent for country 'Russia'
# Updated continent for country 'Russia'
# Updated continent for country 'Fiji'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Zimbabwe'
# Updated continent for country 'Greece'
# Updated continent for country 'Mexico'
# Updated continent for country 'Afghanistan'
# Error updating continent for country 'Democratic Republic': "Invalid Country Name: 'Democratic Republic'"
# Updated continent for country 'Japan'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Chile'
# Updated continent for country 'Pakistan'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Peru'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Japan'
# Error updating continent for country 'India region': "Invalid Country Name: 'India region'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Nicaragua'
# Error updating continent for country 'California': "Invalid Country Name: 'California'"
# Updated continent for country 'Chile'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Japan'
# Error updating continent for country 'Banda Sea': "Invalid Country Name: 'Banda Sea'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Philippines'
# Updated continent for country 'Japan'
# Error updating continent for country 'India region': "Invalid Country Name: 'India region'"
# Updated continent for country 'Indonesia'
# Error updating continent for country '2004 Sumatra - Andaman Islands Earthquake': "Invalid Country Name: '2004 Sumatra - Andaman Islands Earthquake'"
# Error updating continent for country 'Macquarie Island': "Invalid Country Name: 'Macquarie Island'"
# Updated continent for country 'Cayman Islands'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Indonesia'
# Updated continent for country 'New Zealand'
# Updated continent for country 'Colombia'
# Error updating continent for country 'Timor Leste': "Invalid Country Name: 'Timor Leste'"
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Canada'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Nicaragua'
# Updated continent for country 'Philippines'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Chile'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Russia'
# Updated continent for country 'Chile'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Vanuatu'
# Error updating continent for country 'Afghanistan-Tajikistan-Pakistan region': "Invalid Country Name: 'Afghanistan-Tajikistan-Pakistan region'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'New Caledonia'
# Updated continent for country 'Iran'
# Updated continent for country 'Panama'
# Error updating continent for country 'California': "Invalid Country Name: 'California'"
# Updated continent for country 'Taiwan'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Philippines'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Russia'
# Updated continent for country 'Japan'
# Updated continent for country 'Russia'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'Myanmar'
# Updated continent for country 'New Zealand'
# Error updating continent for country 'Scotia Sea': "Invalid Country Name: 'Scotia Sea'"
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Chile'
# Updated continent for country 'Russia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Japan'
# Updated continent for country 'Algeria'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Mexico'
# Updated continent for country 'Guatemala'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Papua New Guinea'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'India'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Northern Mariana Islands'
# Updated continent for country 'Panama'
# Updated continent for country 'Iran'
# Updated continent for country 'Chile'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Guam'
# Updated continent for country 'Chile'
# Updated continent for country 'Mexico'
# Updated continent for country 'Taiwan'
# Updated continent for country 'Chile'
# Updated continent for country 'Philippines'
# Updated continent for country 'Afghanistan'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Turkey'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Solomon Islands'
# Updated continent for country 'Japan'
# Updated continent for country 'Japan'
# Updated continent for country 'China'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Indonesia'
# Updated continent for country 'Guam'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Greece'
# Updated continent for country 'Peru'
# Updated continent for country 'Peru'
# Updated continent for country 'Peru'
# Updated continent for country 'Peru'
# Updated continent for country 'Papua New Guinea'
# Updated continent for country 'Japan'
# Updated continent for country 'Indonesia'
# Error updating continent for country 'Washington': "Invalid Country Name: 'Washington'"
# Updated continent for country 'Indonesia'
# Updated continent for country 'Indonesia'
# Updated continent for country 'El Salvador'
# Updated continent for country 'India'
# Updated continent for country 'Indonesia'
# Updated continent for country 'El Salvador'
# Error updating continent for country 'Alaska': "Invalid Country Name: 'Alaska'"
# Updated continent for country 'Vanuatu'
# Updated continent for country 'Philippines'
# Updated continent for country 'Philippines'
# Saved updated DataFrame to 'earthquake5.csv'

# %%
df=pd.read_csv("earthquake5.csv")
df.isnull().sum()
# Out:
# title          0
# magnitude      0
# date_time      0
# cdi            0
# mmi            0
# alert        367
# tsunami        0
# sig            0
# net            0
# nst            0
# dmin           0
# gap            0
# magType        0
# depth          0
# latitude       0
# longitude      0
# location       5
# continent     54
# country        5
# dtype: int64

# %%
print(f"The number of country: {df2['country'].nunique()} \n")

print(f"Country list: {df2['country'].unique()} \n")

country_frequency=df2["country"].value_counts()
print(country_frequency)
# Out:
# The number of country: 100
#
# Country list: ['Solomon Islands' 'Indonesia' nan 'Tonga' 'the Fiji Islands' 'Panama'
#  'Mexico' 'Taiwan' 'Vanuatu' 'Papua New Guinea' 'China'
#  'the Kermadec Islands' 'Philippines' 'Brazil' 'Peru' 'Argentina'
#  'Nicaragua' 'the Loyalty Islands' 'New Caledonia' 'Japan' 'New Zealand'
#  'Kermadec Islands region' 'Alaska' 'Cyprus' 'Timor Leste' 'Flores Sea'
#  'Vanuatu region' 'South Sandwich Islands region' 'Haiti'
#  'Wallis and Futuna' 'Mauritius - Reunion region' 'Russia'
#  'South Shetland Islands' 'Mongolia' 'Chile' 'Greece'
#  'central Mid-Atlantic Ridge' 'NV Earthquake' 'Banda Sea' 'Idaho'
#  'Jamaica' 'Turkey' 'Fiji' 'South Sandwich Islands' 'Australia' 'CA'
#  'El Salvador' 'Ecuador' 'Prince Edward Islands region' 'Molucca Sea'
#  'Svalbard and Jan Mayen' 'Canada' 'Venezuela' 'Hawaii' 'Bolivia'
#  'Honduras' 'Bouvet Island region' 'Costa Rica' 'Iraq' 'Russia region'
#  'New Zealand region' 'Guatemala' 'Botswana' 'California' 'Tajikistan'
#  'Italy' 'Fiji region' 'Myanmar' 'Northern Mariana Islands' 'Afghanistan'
#  'India' 'India region' 'Barbados' 'Japan region' 'Nepal' 'Guam'
#  'Micronesia region' 'Scotia Sea' 'Okhotsk' 'Pakistan' 'Colombia'
#  'northern Mid-Atlantic Ridge' 'Iran'
#  'off the west coast of northern Sumatra' 'MX' 'Samoa' 'Kyrgyzstan'
#  'Philippine Islands region' 'Ant' 'Martinique' 'S' 'the Kuril Islands'
#  'Kuril Islands' 'Zimbabwe' 'Democratic Republic'
#  '2004 Sumatra - Andaman Islands Earthquake' 'Macquarie Island'
#  'Cayman Islands' 'Afghanistan-Tajikistan-Pakistan region' 'Algeria'
#  'Washington']
#
# Indonesia            105
# Papua New Guinea      67
# Japan                 61
# Chile                 48
# Vanuatu               41
#                     ...
# Jamaica                1
# Idaho                  1
# Micronesia region      1
# NV Earthquake          1
# Washington             1
# Name: country, Length: 100, dtype: int64

# %%
df=pd.read_csv("earthquake5.csv")

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isna(), cmap='Greys', yticklabels=False)
plt.title('Missing Data Heatmap')
plt.show()

# %%
missing_country= df[df['country'].isnull()] #show missing countries and where its located on the data
missing_country
# Out:
#         title  magnitude         date_time  cdi  mmi  alert  tsunami  sig net  \
# 2    M 7.0 -         7.0  12-11-2022 07:09    3    3  green        1  755  us
# 4    M 6.6 -         6.6  09-11-2022 10:14    0    2  green        1  670  us
# 19   M 6.9 -         6.9  19-05-2022 10:13    2    5  green        1  733  us
# 68   M 6.9 -         6.9  01-05-2021 01:27    7    6  green        1  919  us
# 246  M 6.9 -         6.9  28-05-2016 05:38    3    3  green        1  733  us
#
#      nst   dmin   gap magType    depth  latitude  longitude location  \
# 2    147  3.125  18.0     mww  579.000  -20.0508   -178.346      NaN
# 4    131  4.998  27.0     mww  624.464  -25.5948    178.278      NaN
# 19   127  0.371  45.0     mww   10.000  -54.1325    159.027      NaN
# 68     0  2.619  35.0     mww   43.000   38.2296    141.665      NaN
# 246    0  5.485  19.0     mww  405.690  -21.9724   -178.204      NaN
#
#     continent country
# 2     Oceania     NaN
# 4         NaN     NaN
# 19        NaN     NaN
# 68       Asia     NaN
# 246       NaN     NaN

# %%
# Features with null values
print(f"Features with null values count before cleaning:'\n'{df.isnull().sum()[df.isnull().sum() > 0]},'\n'")

print(f"Features with null values count before cleaning:'\n'{df2.isnull().sum()[df.isnull().sum() > 0]}")
# Out:
# Features with null values count before cleaning:'
# 'alert        367
# location       5
# continent    576
# country      298
# dtype: int64,'
# '
# Features with null values count before cleaning:'
# 'alert        367
# location       5
# continent    147
# country       72
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      782 non-null    object
#  1   magnitude  782 non-null    float64
#  2   date_time  782 non-null    object
#  3   cdi        782 non-null    int64
#  4   mmi        782 non-null    int64
#  5   alert      415 non-null    object
#  6   tsunami    782 non-null    int64
#  7   sig        782 non-null    int64
#  8   net        782 non-null    object
#  9   nst        782 non-null    int64
#  10  dmin       782 non-null    float64
#  11  gap        782 non-null    float64
#  12  magType    782 non-null    object
#  13  depth      782 non-null    float64
#  14  latitude   782 non-null    float64
#  15  longitude  782 non-null    float64
#  16  location   777 non-null    object
#  17  continent  206 non-null    object
#  18  country    777 non-null    object
# dtypes: float64(6), int64(5), object(8)
# memory usage: 116.2+ KB
# None

# %%
print(df.describe())
# Out:
#         magnitude         cdi         mmi     tsunami          sig  \
# count  782.000000  782.000000  782.000000  782.000000   782.000000
# mean     6.941125    4.333760    5.964194    0.388747   870.108696
# std      0.445514    3.169939    1.462724    0.487778   322.465367
# min      6.500000    0.000000    1.000000    0.000000   650.000000
# 25%      6.600000    0.000000    5.000000    0.000000   691.000000
# 50%      6.800000    5.000000    6.000000    0.000000   754.000000
# 75%      7.100000    7.000000    7.000000    1.000000   909.750000
# max      9.100000    9.000000    9.000000    1.000000  2910.000000
#
#               nst        dmin         gap       depth    latitude   longitude
# count  782.000000  782.000000  782.000000  782.000000  782.000000  782.000000
# mean   230.250639    1.325757   25.038990   75.883199    3.538100   52.609199
# std    250.188177    2.218805   24.225067  137.277078   27.303429  117.898886
# min      0.000000    0.000000    0.000000    2.700000  -61.848400 -179.968000
# 25%      0.000000    0.000000   14.625000   14.000000  -14.595600  -71.668050
# 50%    140.000000    0.000000   20.000000   26.295000   -2.572500  109.426000
# 75%    445.000000    1.863000   30.000000   49.750000   24.654500  148.941000
# max    934.000000   17.654000  239.000000  670.810000   71.631200  179.662000

# %% [markdown]
# ### The distribution of frequency and magnitude to understand the skewness of the data

# %%
plt.hist(df['magnitude'], bins=25, histtype="bar", color="green")
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.title('Distribution of Magnitude')
plt.show()

# %% [markdown]
# ### Analyze categorical variables

# %%
df= pd.read_csv('earthquake_data.csv')
df.head()
# Out:
#                                           title  magnitude         date_time  \
# 0  M 7.0 - 18 km SW of Malango, Solomon Islands        7.0  22-11-2022 02:03
# 1      M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9  18-11-2022 13:37
# 2                                      M 7.0 -         7.0  12-11-2022 07:09
# 3           M 7.3 - 205 km ESE of Neiafu, Tonga        7.3  11-11-2022 10:48
# 4                                      M 6.6 -         6.6  09-11-2022 10:14
#
#    cdi  mmi  alert  tsunami  sig net  nst   dmin   gap magType    depth  \
# 0    8    7  green        1  768  us  117  0.509  17.0     mww   14.000
# 1    4    4  green        0  735  us   99  2.229  34.0     mww   25.000
# 2    3    3  green        1  755  us  147  3.125  18.0     mww  579.000
# 3    5    5  green        1  833  us  149  1.865  21.0     mww   37.000
# 4    0    2  green        1  670  us  131  4.998  27.0     mww  624.464
#
#    latitude  longitude                  location continent          country
# 0   -9.7963    159.596  Malango, Solomon Islands   Oceania  Solomon Islands
# 1   -4.9559    100.738       Bengkulu, Indonesia       NaN              NaN
# 2  -20.0508   -178.346                       NaN   Oceania             Fiji
# 3  -19.2918   -172.129             Neiafu, Tonga       NaN              NaN
# 4  -25.5948    178.278                       NaN       NaN              NaN

# %%
df1 = pd.read_csv("earthquake1.csv")

# %%
df = pd.read_csv("earthquake_data.csv")

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isna(), cmap='Greys', yticklabels=False)
plt.title('Missing Data Heatmap')
plt.show()

# %%
df.describe()
# Out:
#         magnitude         cdi         mmi     tsunami          sig  \
# count  782.000000  782.000000  782.000000  782.000000   782.000000
# mean     6.941125    4.333760    5.964194    0.388747   870.108696
# std      0.445514    3.169939    1.462724    0.487778   322.465367
# min      6.500000    0.000000    1.000000    0.000000   650.000000
# 25%      6.600000    0.000000    5.000000    0.000000   691.000000
# 50%      6.800000    5.000000    6.000000    0.000000   754.000000
# 75%      7.100000    7.000000    7.000000    1.000000   909.750000
# max      9.100000    9.000000    9.000000    1.000000  2910.000000
#
#               nst        dmin         gap       depth    latitude   longitude
# count  782.000000  782.000000  782.000000  782.000000  782.000000  782.000000
# mean   230.250639    1.325757   25.038990   75.883199    3.538100   52.609199
# std    250.188177    2.218805   24.225067  137.277078   27.303429  117.898886
# min      0.000000    0.000000    0.000000    2.700000  -61.848400 -179.968000
# 25%      0.000000    0.000000   14.625000   14.000000  -14.595600  -71.668050
# 50%    140.000000    0.000000   20.000000   26.295000   -2.572500  109.426000
# 75%    445.000000    1.863000   30.000000   49.750000   24.654500  148.941000
# max    934.000000   17.654000  239.000000  670.810000   71.631200  179.662000
